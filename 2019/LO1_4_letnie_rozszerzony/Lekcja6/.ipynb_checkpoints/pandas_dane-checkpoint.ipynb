# %% [markdown]
# ## Pandas analiza danych ##

# %%
import pandas as pd
# import matplotlib.pyplot as plt

# %%
df = pd.read_excel('python_dane.xlsx')

# %%
df.head(8)
# Out:
#    Lp       Nazwisko        Imię  wiek  wzrost  waga  Język polski  \
# 0   1            Bęc  Aleksandra    14   175.8  54.7             2
# 1   2         Błazik    Wiktoria    18   174.9  59.2             3
# 2   3          Borys       Hanna    16   160.9  72.8             4
# 3   4       Bralczyk         Iwo    17   176.3  73.8             3
# 4   5          Chyrc    Karolina    13   165.2  68.5             3
# 5   6     Ciarcińska       Zofia    15   171.1  64.7             2
# 6   7       Dubowicz      Rusłan    10   177.5  57.1             5
# 7   8  Dzierżanowska    Wiktoria    12   172.8  52.6             6
#
#    Matematyka  Geografia  Fizyka  Historia  Informatyka  Język\nangielski  \
# 0           5          2       2         4            3                 3
# 1           3          5       5         6            5                 6
# 2           4          6       6         3            6                 5
# ...

# %%
df.tail(5)
# Out:
#     Lp    Nazwisko     Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 43  44  Wasilewska    Julia    18   174.1  58.9             4           3
# 44  45  Wasilewska  Natalia    16   162.4  57.3             2           5
# 45  46  Wierzbicki   Antoni    11   176.9  60.4             2           4
# 46  47    Wodnicki      Jan    15   159.9  59.6             3           3
# 47  48      Wysmyk    Kinga    15   178.3  70.6             5           6
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 43          6       3         3            5                 6       4
# 44          5       2         4            5                 3       5
# 45          3       5         5            5                 3       5
# 46          5       6         6            5                 2       3
# 47          3       2         4            5                 5       5

# %%
df.wzrost.mean()
# Out:
# 167.3666666666667

# %%
df.waga.mean()
# Out:
# 62.125

# %%
df.wzrost.max()
# Out:
# 180.0

# %%
df[df.wzrost>=180]
# Out:
#     Lp  Nazwisko    Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 11  12  Hornecki  Daniel    14   180.0  55.8             4           4
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 11          2       4         5            4                 4       6

# %%
# df[df.wiek == 14].wzrost.mean()
df[df.wiek == 14]
# Out:
#     Lp  Nazwisko        Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 0    1       Bęc  Aleksandra    14   175.8  54.7             2           5
# 11  12  Hornecki      Daniel    14   180.0  55.8             4           4
# 23  24    Molęda       Piotr    14   179.9  55.6             3           4
# 29  30  Owczarek    Dominika    14   176.1  60.1             5           3
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 0           2       2         4            3                 3       4
# 11          2       4         5            4                 4       6
# 23          2       6         2            5                 2       4
# 29          5       6         4            3                 6       2

# %%
print(df.groupby(df.wiek).wzrost.mean())
# Out:
# wiek
# 9     173.200000
# 10    168.150000
# 11    160.628571
# 12    170.500000
# 13    166.566667
# 14    177.950000
# 15    165.566667
# 16    162.383333
# 17    170.800000
# 18    174.100000
# Name: wzrost, dtype: float64

# %%
df[df.Imię == 'Piotr']
# Out:
#     Lp Nazwisko   Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 15  16   Konkol  Piotr    17   178.7  68.9             3           3
# 23  24   Molęda  Piotr    14   179.9  55.6             3           4
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 15          2       5         2            3                 5       6
# 23          2       6         2            5                 2       4

# %%
df[df.wzrost>175]
# Out:
#     Lp     Nazwisko        Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 0    1          Bęc  Aleksandra    14   175.8  54.7             2           5
# 3    4     Bralczyk         Iwo    17   176.3  73.8             3           2
# 6    7     Dubowicz      Rusłan    10   177.5  57.1             5           4
# 11  12     Hornecki      Daniel    14   180.0  55.8             4           4
# 15  16       Konkol       Piotr    17   178.7  68.9             3           3
# 17  18  Kościelniak      Joanna    13   177.4  58.6             6           3
# 23  24       Molęda       Piotr    14   179.9  55.6             3           4
# 24  25        Moroz  Franciszek    16   175.2  60.0             4           4
# 29  30     Owczarek    Dominika    14   176.1  60.1             5           3
# 33  34     Radziwon     Natalia    15   178.8  56.9             5           2
# 40  41     Tomańska     Natalia    17   177.5  55.3             2           4
# ...

# %%
df.wzrost.min()
# Out:
# 151.4

# %%
df[df.wzrost == df.wzrost.min()]
# Out:
#     Lp  Nazwisko      Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 32  33  Pomazana  Wiktoria    16   151.4  66.4             3           5
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 32          4       5         3            3                 6       5

# %%
df[df.waga == df.waga.min()]
# Out:
#     Lp   Nazwisko     Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 41  42  Trybalski  Jonatan    13   175.5  50.4             6           2
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 41          3       2         4            6                 2       5

# %%
df.columns
# Out:
# Index(['Lp', 'Nazwisko', 'Imię', 'wiek', 'wzrost', 'waga', 'Język polski',
#        'Matematyka', 'Geografia', 'Fizyka', 'Historia', 'Informatyka',
#        'Język\nangielski', 'Chemia'],
#       dtype='object')

# %%
df[df.Informatyka >= 5].sort_values(by='Informatyka', ascending=False)
# Out:
#     Lp     Nazwisko      Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 34  35     Sadowski    Wiktor    16   165.1  71.1             2           2
# 36  37   Sobolewski     Jakub    15   165.2  66.1             5           2
# 22  23     Miłuński      Igor    13   157.7  52.8             5           5
# 41  42    Trybalski   Jonatan    13   175.5  50.4             6           2
# 2    3        Borys     Hanna    16   160.9  72.8             4           4
# 46  47     Wodnicki       Jan    15   159.9  59.6             3           3
# 45  46   Wierzbicki    Antoni    11   176.9  60.4             2           4
# 44  45   Wasilewska   Natalia    16   162.4  57.3             2           5
# 43  44   Wasilewska     Julia    18   174.1  58.9             4           3
# 38  39  Szwedkowicz       Jan    15   160.6  53.0             6           4
# 1    2       Błazik  Wiktoria    18   174.9  59.2             3           3
# ...

# %%
df.sort_values(by = 'Informatyka', ascending=False ).head(6)
# Out:
#     Lp    Nazwisko     Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 22  23    Miłuński     Igor    13   157.7  52.8             5           5
# 2    3       Borys    Hanna    16   160.9  72.8             4           4
# 36  37  Sobolewski    Jakub    15   165.2  66.1             5           2
# 34  35    Sadowski   Wiktor    16   165.1  71.1             2           2
# 41  42   Trybalski  Jonatan    13   175.5  50.4             6           2
# 47  48      Wysmyk    Kinga    15   178.3  70.6             5           6
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 22          2       3         3            6                 3       3
# 2           6       6         3            6                 5       5
# 36          6       5         3            6                 4       2
# 34          2       4         6            6                 3       3
# 41          3       2         4            6                 2       5
# ...

# %%
fr1 = df[df.wzrost > (df.wzrost.max()-2)]
fr1
# Out:
#     Lp  Nazwisko     Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 11  12  Hornecki   Daniel    14   180.0  55.8             4           4
# 15  16    Konkol    Piotr    17   178.7  68.9             3           3
# 23  24    Molęda    Piotr    14   179.9  55.6             3           4
# 33  34  Radziwon  Natalia    15   178.8  56.9             5           2
# 47  48    Wysmyk    Kinga    15   178.3  70.6             5           6
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 11          2       4         5            4                 4       6
# 15          2       5         2            3                 5       6
# 23          2       6         2            5                 2       4
# 33          3       6         6            4                 3       5
# 47          3       2         4            5                 5       5

# %%
fr1
# Out:
#     Lp  Nazwisko     Imię  wiek  wzrost  waga  Język polski  Matematyka  \
# 11  12  Hornecki   Daniel    14   180.0  55.8             4           4
# 15  16    Konkol    Piotr    17   178.7  68.9             3           3
# 23  24    Molęda    Piotr    14   179.9  55.6             3           4
# 33  34  Radziwon  Natalia    15   178.8  56.9             5           2
# 47  48    Wysmyk    Kinga    15   178.3  70.6             5           6
#
#     Geografia  Fizyka  Historia  Informatyka  Język\nangielski  Chemia
# 11          2       4         5            4                 4       6
# 15          2       5         2            3                 5       6
# 23          2       6         2            5                 2       4
# 33          3       6         6            4                 3       5
# 47          3       2         4            5                 5       5

# %%
fr1.to_excel('najwyzsi.xlsx', sheet_name='osoby_najwyzsze')

# %%
fr1.to_csv('osoby najwyzsze.csv')
