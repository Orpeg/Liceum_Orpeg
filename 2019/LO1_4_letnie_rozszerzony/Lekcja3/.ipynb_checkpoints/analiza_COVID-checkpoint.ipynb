# %% [markdown]
# ## Analiza koronowirusa dane z 15 marca 2020

# %% [markdown]
# ![Python](pandas.jpg)

# %%
# import bibliotek
import pandas as pd
import matplotlib.pyplot as plt

# %%
# wczytujemy plik z internetu
url = 'https://www.ecdc.europa.eu/sites/default/files/documents/COVID-19-geographic-disbtribution-worldwide-2020-03-16.xls'

# %%
# wczytanie danych do dataframe o nazwie frame
frame = pd.read_excel(url, sheet_name=0)

# %%
frame.head()
# Out:
#      DateRep   CountryExp  NewConfCases  NewDeaths GeoId Gaul1Nuts1  \
# 0 2020-03-16  Afghanistan             6        0.0    AF        NaN
# 1 2020-03-15  Afghanistan             3        0.0    AF        NaN
# 2 2020-03-11  Afghanistan             3        0.0    AF        NaN
# 3 2020-03-08  Afghanistan             3        0.0    AF        NaN
# 4 2020-03-02  Afghanistan             0        0.0    AF        NaN
#
#            EU
# 0  Non-EU/EEA
# 1  Non-EU/EEA
# 2  Non-EU/EEA
# 3  Non-EU/EEA
# 4  Non-EU/EEA

# %%
frame.shape
# Out:
# (5250, 7)

# %%
# pokazuje typy zmiennych w kolumnach
frame.dtypes
# Out:
# DateRep         datetime64[ns]
# CountryExp              object
# NewConfCases             int64
# NewDeaths              float64
# GeoId                   object
# Gaul1Nuts1              object
# EU                      object
# dtype: object

# %%
# to jest mały trick- tworzymy kolumnę 'time' aby format daty był kompatybilny z pandas
frame['time'] = pd.to_datetime(frame.DateRep)

# %%
# kolumny
frame.columns
# Out:
# Index(['DateRep', 'CountryExp', 'NewConfCases', 'NewDeaths', 'GeoId',
#        'Gaul1Nuts1', 'EU', 'time'],
#       dtype='object')

# %%
frame[frame.CountryExp == "Poland"]
# Out:
#         DateRep CountryExp  NewConfCases  NewDeaths GeoId Gaul1Nuts1  EU  \
# 3940 2020-03-16     Poland            21        0.0    PL        NaN  EU
# 3941 2020-03-15     Poland            36        1.0    PL        NaN  EU
# 3942 2020-03-14     Poland            19        1.0    PL        NaN  EU
# 3943 2020-03-13     Poland            18        1.0    PL        NaN  EU
# 3944 2020-03-12     Poland             9        0.0    PL        NaN  EU
# 3945 2020-03-11     Poland             5        0.0    PL        NaN  EU
# 3946 2020-03-10     Poland             6        0.0    PL        NaN  EU
# 3947 2020-03-09     Poland             5        0.0    PL        NaN  EU
# 3948 2020-03-08     Poland             1        0.0    PL        NaN  EU
# 3949 2020-03-07     Poland             4        0.0    PL        NaN  EU
# 3950 2020-03-04     Poland             1        0.0    PL        NaN  EU
#
#            time
# 3940 2020-03-16
# 3941 2020-03-15
# 3942 2020-03-14
# 3943 2020-03-13
# 3944 2020-03-12
# 3945 2020-03-11
# 3946 2020-03-10
# 3947 2020-03-09
# 3948 2020-03-08
# 3949 2020-03-07
# 3950 2020-03-04

# %%
# grupowanie wg powtarzających się danych w kolumnie, sumowanie i sortowanie
frame.groupby(frame.CountryExp).sum().sort_values(by = 'NewConfCases', ascending = False)
# Out:
#                                             NewConfCases  NewDeaths
# CountryExp
# China                                              81020     3217.0
# Italy                                              23980     1811.0
# Iran                                               13938      724.0
# South Korea                                         8236       75.0
# Spain                                               7753      288.0
# France                                              5423      127.0
# Germany                                             4838       12.0
# United States of America                            3774       69.0
# Switzerland                                         1933       10.0
# United Kingdom                                      1308       35.0
# Netherlands                                         1135       20.0
# Norway                                              1077        1.0
# Sweden                                              1032        3.0
# Belgium                                              886        4.0
# Denmark                                              875        1.0
# Austria                                              860        1.0
# Japan                                                814       24.0
# Cases on an international conveyance Japan           696        7.0
# Malaysia                                             428        0.0
# Qatar                                                401        0.0
# Greece                                               331        4.0
# Canada                                               304        1.0
# Australia                                            298        5.0
# switzerland                                          267        3.0
# Czech Republic                                       267        0.0
# Finland                                              267        0.0
# Israel                                               250        0.0
# Portugal                                             245        0.0
# Singapore                                            226        0.0
# Slovenia                                             219        0.0
# ...                                                  ...        ...
# Cuba                                                   4        0.0
# Burkina Faso                                           3        0.0
# Ukraine                                                3        0.0
# Bangladesh                                             3        0.0
# Kenya                                                  3        0.0
# Seychelles                                             3        0.0
# Saint Lucia                                            2        0.0
# Namibia                                                2        0.0
# Nigeria                                                2        0.0
# Kosovo                                                 2        0.0
# Ghana                                                  2        0.0
# Democratic Republic of the Congo                       2        0.0
# Equatorial Guinea                                      1        0.0
# Mongolia                                               1        0.0
# Mauritania                                             1        0.0
# Antigua and Barbuda                                    1        0.0
# Bahamas                                                1        0.0
# Holy See                                               1        0.0
# Bhutan                                                 1        0.0
# Guatemala                                              1        1.0
# Saint Vincent and the Grenadines                       1        0.0
# Guinea                                                 1        0.0
# Togo                                                   1        0.0
# Central African Republic                               1        0.0
# Congo                                                  1        0.0
# Swaziland                                              1        0.0
# Suriname                                               1        0.0
# Sudan                                                  1        1.0
# Gabon                                                  1        0.0
# Nepal                                                  1        0.0
#
# [143 rows x 2 columns]

# %%
# wynik powyżej nie pozwala odczytać danych dla Polski, filtrujemy
data = frame.groupby(frame.CountryExp).sum().sort_values(by='NewConfCases', ascending=False)
data[data.NewConfCases < 300]
# Out:
#                                   NewConfCases  NewDeaths
# CountryExp
# Australia                                  298        5.0
# switzerland                                267        3.0
# Czech Republic                             267        0.0
# Finland                                    267        0.0
# Israel                                     250        0.0
# Portugal                                   245        0.0
# Singapore                                  226        0.0
# Slovenia                                   219        0.0
# Bahrain                                    214        0.0
# Brazil                                     200        0.0
# Iceland                                    178        0.0
# Estonia                                    171        0.0
# Ireland                                    169        2.0
# Philippines                                140       12.0
# Romania                                    139        0.0
# Poland                                     125        3.0
# Iraq                                       124        9.0
# Saudi Arabia                               118        0.0
# Indonesia                                  117        5.0
# Thailand                                   114        1.0
# Kuwait                                     112        0.0
# Egypt                                      110        2.0
# Lebanon                                     99        3.0
# San Marino                                  98        7.0
# India                                       93        2.0
# United Arab Emirates                        86        0.0
# United kingdom                              83        0.0
# Luxembourg                                  77        1.0
# Chile                                       75        0.0
# Peru                                        71        0.0
# ...                                        ...        ...
# Cuba                                         4        0.0
# Burkina Faso                                 3        0.0
# Ukraine                                      3        0.0
# Bangladesh                                   3        0.0
# Kenya                                        3        0.0
# Seychelles                                   3        0.0
# Saint Lucia                                  2        0.0
# Namibia                                      2        0.0
# Nigeria                                      2        0.0
# Kosovo                                       2        0.0
# Ghana                                        2        0.0
# Democratic Republic of the Congo             2        0.0
# Equatorial Guinea                            1        0.0
# Mongolia                                     1        0.0
# Mauritania                                   1        0.0
# Antigua and Barbuda                          1        0.0
# Bahamas                                      1        0.0
# Holy See                                     1        0.0
# Bhutan                                       1        0.0
# Guatemala                                    1        1.0
# Saint Vincent and the Grenadines             1        0.0
# Guinea                                       1        0.0
# Togo                                         1        0.0
# Central African Republic                     1        0.0
# Congo                                        1        0.0
# Swaziland                                    1        0.0
# Suriname                                     1        0.0
# Sudan                                        1        1.0
# Gabon                                        1        0.0
# Nepal                                        1        0.0
#
# [121 rows x 2 columns]

# %%
# analiza wg miesięcy dot. Polski (True) oraz pozostałych krajów
frame.groupby([frame.CountryExp=='Poland', frame.time.dt.month]).sum()
# Out:
#                  NewConfCases  NewDeaths
# CountryExp time
# False      1             9799      213.0
#            2            75377     2708.0
#            3            82086     3583.0
#            12              27        0.0
# True       3              125        3.0

# %%
# analiza w którym dniu tygodnia jest nawięcej przypadków
frame.groupby([frame.CountryExp == 'Poland', frame.time.dt.weekday]).sum()
# Out:
#                  NewConfCases  NewDeaths
# CountryExp time
# False      0            31158     1483.0
#            1            16669      659.0
#            2            17114      757.0
#            3            31510      925.0
#            4            23174      767.0
#            5            24828     1008.0
#            6            22836      905.0
# True       0               26        0.0
#            1                6        0.0
#            2                6        0.0
#            3                9        0.0
#            4               18        1.0
#            5               23        1.0
#            6               37        1.0

# %% [markdown]
# **najwięcej zachorować i zgonów miało miejsce w piątek, sobotę i niedzielę!

# %%
# wkres
data[(data.NewConfCases < 200) & (data.NewConfCases > 100)].plot.barh()
